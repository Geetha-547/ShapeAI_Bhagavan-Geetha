# %%
from keras.datasets import mnist
data=mnist.load_data()

# %%
(x_train,y_train),(x_test,y_test)=data

# %%
x_train[0].shape
# Out:
# (28, 28)

# %%
x_train=x_train.reshape((x_train.shape[0],28*28)).astype('float32')
x_test=x_test.reshape((x_test.shape[0],28*28)).astype('float32')

# %%
x_train=x_train/255
x_test=x_test/255

# %%
from keras.utils import np_utils
 
y_train=np_utils.to_categorical(y_train)
y_test=np_utils.to_categorical(y_test)
num_classes=y_test.shape[1]

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model=Sequential ()
model.add(Dense(32,input_dim=28*28,activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,epochs=10,batch_size=100)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 2s 2ms/step - loss: 0.7511 - accuracy: 0.7918
# Epoch 2/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2075 - accuracy: 0.9403
# Epoch 3/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1540 - accuracy: 0.9543
# Epoch 4/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1248 - accuracy: 0.9625
# Epoch 5/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1048 - accuracy: 0.9688
# Epoch 6/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0957 - accuracy: 0.9713
# Epoch 7/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0839 - accuracy: 0.9742
# Epoch 8/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0777 - accuracy: 0.9761
# Epoch 9/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0718 - accuracy: 0.9776
# Epoch 10/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0647 - accuracy: 0.9801

# %%
scores=model.evaluate(x_test,y_test)
print(scores)
# Out:
# 313/313 [==============================] - 0s 897us/step - loss: 0.1001 - accuracy: 0.9713
# [0.10014048218727112, 0.9713000059127808]
